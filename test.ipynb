# %%
from Queries.prints import *
from Queries.queries import *
from Functions.wikidata_query_functions import *

# %%
number = 5
director = "Christopher Nolan"
actor = "Samuel L. Jackson"
genre = "crime film"
year = 1987
country = "Serbia"

# %%
output_query(query_genre(genre, number))
# Out:
#                  name      directorname   genrename               countryname  \
# 0  North by Northwest  Alfred Hitchcock  crime film  United States of America
# 1  North by Northwest  Alfred Hitchcock  crime film  United States of America
# 2  North by Northwest  Alfred Hitchcock  crime film  United States of America
# 3  North by Northwest  Alfred Hitchcock  crime film  United States of America
# 4  North by Northwest  Alfred Hitchcock  crime film  United States of America
#
#                    year
# 0  1959-01-01T00:00:00Z
# 1  1959-07-01T00:00:00Z
# 2  1959-07-17T00:00:00Z
# 3  1959-08-06T00:00:00Z
# 4  1959-09-11T00:00:00Z

# %%
output_query(query_actor(actor, number))
# Out:
#                 name  directorname              genrename  \
# 0  Maximum Overdrive  Stephen King            comedy film
# 1  Maximum Overdrive  Stephen King            comedy film
# 2        Whale Rider     Niki Caro  coming-of-age fiction
# 3  Maximum Overdrive  Stephen King            horror film
# 4  Maximum Overdrive  Stephen King            horror film
#
#                 countryname                  year
# 0  United States of America  1986-07-25T00:00:00Z
# 1  United States of America  1986-11-20T00:00:00Z
# 2                   Germany  2002-01-01T00:00:00Z
# 3  United States of America  1986-07-25T00:00:00Z
# 4  United States of America  1986-11-20T00:00:00Z

# %%
output_query(query_country(country, number))
# Out:
#                          name       directorname    genrename countryname  \
# 0                     Mamaroš  Momcilo Mrdakovic  comedy film      Serbia
# 1                     Mamaroš  Momcilo Mrdakovic  comedy film      Serbia
# 2               Fade to Black      Oliver Parker   drama film      Serbia
# 3        Born to Be a Warrior        Guido Zurli  action film      Serbia
# 4  Montevideo, God Bless You!  Dragan Bjelogrlić   drama film      Serbia
#
#                    year
# 0  2013-06-25T00:00:00Z
# 1  2013-09-19T00:00:00Z
# 2  2006-01-01T00:00:00Z
# 3  1994-01-01T00:00:00Z
# 4  2010-12-20T00:00:00Z

# %%
output_query(query_director(director, number))
# Out:
#         name       directorname   genrename               countryname  \
# 0  Inception  Christopher Nolan  drama film  United States of America
# 1  Inception  Christopher Nolan  drama film  United States of America
# 2  Inception  Christopher Nolan  drama film  United States of America
# 3  Inception  Christopher Nolan  drama film  United States of America
# 4  Inception  Christopher Nolan  drama film  United States of America
#
#                    year
# 0  2010-07-08T00:00:00Z
# 1  2010-07-16T00:00:00Z
# 2  2010-07-21T00:00:00Z
# 3  2010-07-22T00:00:00Z
# 4  2010-07-29T00:00:00Z

# %%
output_query(query_year(year, number))
# Out:
# Empty DataFrame
# Columns: [name, directorname, genrename, countryname, year]
# Index: []
